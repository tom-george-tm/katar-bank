# %% [markdown]
# # Vision LangGraph – Graph Visualization

# %%
import os
import sys

# Ensure the project root is importable
sys.path.insert(0, os.path.abspath(".."))

from core.graph import vision_graph
from IPython.display import Image, display

g = vision_graph.get_graph()

# Prefer an inline PNG; fall back to Mermaid text if PNG deps aren't installed.
try:
    display(Image(g.draw_mermaid_png()))
except Exception as e:
    print("PNG render failed (showing Mermaid text instead):", repr(e))
    print(g.draw_mermaid())
